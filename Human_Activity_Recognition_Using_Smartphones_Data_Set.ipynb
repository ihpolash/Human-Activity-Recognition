# %%
# !git clone https://github.com/srvds/Human-Activity-Recognition.git
# Out:
# Cloning into 'Human-Activity-Recognition'...
# remote: Enumerating objects: 207, done.
# remote: Total 207 (delta 0), reused 0 (delta 0), pack-reused 207
# Receiving objects: 100% (207/207), 84.69 MiB | 20.19 MiB/s, done.
# Resolving deltas: 100% (86/86), done.
# Checking out files: 100% (52/52), done.

# %%
cd Human-Activity-Recognition/
# Out:
# /content/Human-Activity-Recognition

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Obtain the train data

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_Dataset/train/X_train.txt', delim_whitespace=True, header=None)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#             0         1         2  ...  subject  Activity        ActivityName
# 6216  0.44742 -0.009257 -0.090928  ...       27         3  WALKING_DOWNSTAIRS
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ### Obtain the test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_Dataset/test/X_test.txt', delim_whitespace=True, header=None)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#              0         1         2  ...  subject  Activity  ActivityName
# 1073  0.279018 -0.015557 -0.122886  ...       10         5      STANDING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# ### Data Cleaning

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,"tBodyAccMag-mean()", hist=False).add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-8d7bbf21011e> in <module>()
#       1 sns.set_palette("Set1", desat=0.80)
#       2 facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
# ----> 3 facetgrid.map(sns.distplot,"tBodyAccMag-mean()", hist=False).add_legend()
#       4 plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,            va='center', ha='left',            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
#       5
#
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     750
#     751             # Get the actual data we are going to plot with
# --> 752             plot_data = data_ijk[list(args)]
#     753             if self._dropna:
#     754                 plot_data = plot_data.dropna()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['tBodyAccMag-mean()'], dtype='object')] are in the [columns]"

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index([           nan,            nan,            nan,            nan,
#                   nan,            nan,            nan,            nan,
#                   nan,            nan,
#        ...
#                   nan,            nan,            nan,            nan,
#                   nan,            nan,            nan,      'subject',
#            'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### Stationary and Moving activities are completely different

# %%
train = pd.read_csv('UCI_HAR_Dataset/csv_files/train.csv')
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  Activity  ActivityName
# 0           0.288585          -0.020294  ...         5      STANDING
# 1           0.278419          -0.016411  ...         5      STANDING
# 2           0.279653          -0.019467  ...         5      STANDING
# 3           0.279174          -0.026201  ...         5      STANDING
# 4           0.276629          -0.016570  ...         5      STANDING
#
# [5 rows x 564 columns]

# %%
test = pd.read_csv('UCI_HAR_Dataset/csv_files/test.csv')
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  Activity  ActivityName
# 0           0.257178          -0.023285  ...         5      STANDING
# 1           0.286027          -0.013163  ...         5      STANDING
# 2           0.275485          -0.026050  ...         5      STANDING
# 3           0.270298          -0.032614  ...         5      STANDING
# 4           0.274833          -0.027848  ...         5      STANDING
#
# [5 rows x 564 columns]

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMag-mean()', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMag-mean()'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMag-mean()'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMag-mean()'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMag-mean()'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMag-mean()'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMag-mean()'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMag-mean()',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='ActivityName', y='angle(X,gravityMean)', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %%
sns.boxplot(x='ActivityName', y='angle(Y,gravityMean)', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ## Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.503s...
# [t-SNE] Computed neighbors for 7352 samples in 39.411s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.053s
# [t-SNE] Iteration 50: error = 124.7870712, gradient norm = 0.0259038 (50 iterations in 9.999s)
# [t-SNE] Iteration 100: error = 106.7838440, gradient norm = 0.0308988 (50 iterations in 3.276s)
# [t-SNE] Iteration 150: error = 100.5753479, gradient norm = 0.0194796 (50 iterations in 2.397s)
# [t-SNE] Iteration 200: error = 97.2328873, gradient norm = 0.0144493 (50 iterations in 2.286s)
# [t-SNE] Iteration 250: error = 94.9926910, gradient norm = 0.0128797 (50 iterations in 2.258s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.992691
# [t-SNE] Iteration 300: error = 4.1128659, gradient norm = 0.0015619 (50 iterations in 2.069s)
# [t-SNE] Iteration 350: error = 3.2065625, gradient norm = 0.0009960 (50 iterations in 1.903s)
# [t-SNE] Iteration 400: error = 2.7768269, gradient norm = 0.0007151 (50 iterations in 1.955s)
# [t-SNE] Iteration 450: error = 2.5132439, gradient norm = 0.0005700 (50 iterations in 1.946s)
# [t-SNE] Iteration 500: error = 2.3299038, gradient norm = 0.0004832 (50 iterations in 1.976s)
# [t-SNE] Iteration 550: error = 2.1920092, gradient norm = 0.0004130 (50 iterations in 1.986s)
# [t-SNE] Iteration 600: error = 2.0827551, gradient norm = 0.0003688 (50 iterations in 1.991s)
# [t-SNE] Iteration 650: error = 1.9930117, gradient norm = 0.0003283 (50 iterations in 2.030s)
# [t-SNE] Iteration 700: error = 1.9173744, gradient norm = 0.0003026 (50 iterations in 2.013s)
# [t-SNE] Iteration 750: error = 1.8523064, gradient norm = 0.0002817 (50 iterations in 2.024s)
# [t-SNE] Iteration 800: error = 1.7956853, gradient norm = 0.0002588 (50 iterations in 2.045s)
# [t-SNE] Iteration 850: error = 1.7455676, gradient norm = 0.0002417 (50 iterations in 2.031s)
# [t-SNE] Iteration 900: error = 1.7011335, gradient norm = 0.0002263 (50 iterations in 2.051s)
# [t-SNE] Iteration 950: error = 1.6611171, gradient norm = 0.0002136 (50 iterations in 2.048s)
# [t-SNE] Iteration 1000: error = 1.6245947, gradient norm = 0.0001994 (50 iterations in 2.056s)
# [t-SNE] KL divergence after 1000 iterations: 1.624595
# Done..
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.512s...
# [t-SNE] Computed neighbors for 7352 samples in 40.371s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.071s
# [t-SNE] Iteration 50: error = 113.9442368, gradient norm = 0.0204094 (50 iterations in 3.806s)
# [t-SNE] Iteration 100: error = 97.5425339, gradient norm = 0.0151187 (50 iterations in 2.497s)
# [t-SNE] Iteration 150: error = 93.1223297, gradient norm = 0.0087664 (50 iterations in 2.023s)
# [t-SNE] Iteration 200: error = 91.1577759, gradient norm = 0.0060825 (50 iterations in 1.870s)
# [t-SNE] Iteration 250: error = 89.9989243, gradient norm = 0.0044533 (50 iterations in 1.880s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.998924
# [t-SNE] Iteration 300: error = 3.5735092, gradient norm = 0.0014640 (50 iterations in 1.874s)
# [t-SNE] Iteration 350: error = 2.8139133, gradient norm = 0.0007489 (50 iterations in 1.949s)
# [t-SNE] Iteration 400: error = 2.4323239, gradient norm = 0.0005199 (50 iterations in 1.920s)
# [t-SNE] Iteration 450: error = 2.2137775, gradient norm = 0.0004021 (50 iterations in 1.938s)
# [t-SNE] Iteration 500: error = 2.0685689, gradient norm = 0.0003340 (50 iterations in 1.947s)
# [t-SNE] Iteration 550: error = 1.9630345, gradient norm = 0.0002827 (50 iterations in 1.927s)
# [t-SNE] Iteration 600: error = 1.8815123, gradient norm = 0.0002461 (50 iterations in 1.921s)
# [t-SNE] Iteration 650: error = 1.8165274, gradient norm = 0.0002169 (50 iterations in 1.960s)
# [t-SNE] Iteration 700: error = 1.7629720, gradient norm = 0.0001977 (50 iterations in 1.929s)
# [t-SNE] Iteration 750: error = 1.7174244, gradient norm = 0.0001810 (50 iterations in 1.929s)
# [t-SNE] Iteration 800: error = 1.6783386, gradient norm = 0.0001653 (50 iterations in 1.930s)
# [t-SNE] Iteration 850: error = 1.6445255, gradient norm = 0.0001509 (50 iterations in 1.942s)
# [t-SNE] Iteration 900: error = 1.6148648, gradient norm = 0.0001413 (50 iterations in 1.971s)
# [t-SNE] Iteration 950: error = 1.5884020, gradient norm = 0.0001329 (50 iterations in 1.951s)
# [t-SNE] Iteration 1000: error = 1.5646949, gradient norm = 0.0001256 (50 iterations in 1.939s)
# [t-SNE] KL divergence after 1000 iterations: 1.564695
# Done..
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.506s...
# [t-SNE] Computed neighbors for 7352 samples in 40.703s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.127s
# [t-SNE] Iteration 50: error = 106.0060883, gradient norm = 0.0145607 (50 iterations in 3.527s)
# [t-SNE] Iteration 100: error = 90.7219696, gradient norm = 0.0107636 (50 iterations in 2.363s)
# [t-SNE] Iteration 150: error = 87.5557556, gradient norm = 0.0069467 (50 iterations in 2.066s)
# [t-SNE] Iteration 200: error = 86.2526398, gradient norm = 0.0044534 (50 iterations in 2.064s)
# [t-SNE] Iteration 250: error = 85.5034256, gradient norm = 0.0030479 (50 iterations in 2.047s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.503426
# [t-SNE] Iteration 300: error = 3.1408634, gradient norm = 0.0014020 (50 iterations in 2.009s)
# [t-SNE] Iteration 350: error = 2.4946063, gradient norm = 0.0006519 (50 iterations in 1.993s)
# [t-SNE] Iteration 400: error = 2.1732652, gradient norm = 0.0004245 (50 iterations in 1.990s)
# [t-SNE] Iteration 450: error = 1.9882784, gradient norm = 0.0003148 (50 iterations in 1.983s)
# [t-SNE] Iteration 500: error = 1.8695626, gradient norm = 0.0002528 (50 iterations in 1.997s)
# [t-SNE] Iteration 550: error = 1.7856309, gradient norm = 0.0002117 (50 iterations in 2.014s)
# [t-SNE] Iteration 600: error = 1.7228947, gradient norm = 0.0001820 (50 iterations in 2.028s)
# [t-SNE] Iteration 650: error = 1.6739213, gradient norm = 0.0001590 (50 iterations in 2.019s)
# [t-SNE] Iteration 700: error = 1.6342342, gradient norm = 0.0001442 (50 iterations in 2.021s)
# [t-SNE] Iteration 750: error = 1.6015506, gradient norm = 0.0001301 (50 iterations in 2.067s)
# [t-SNE] Iteration 800: error = 1.5741490, gradient norm = 0.0001173 (50 iterations in 2.028s)
# [t-SNE] Iteration 850: error = 1.5506287, gradient norm = 0.0001111 (50 iterations in 2.013s)
# [t-SNE] Iteration 900: error = 1.5301657, gradient norm = 0.0001020 (50 iterations in 2.032s)
# [t-SNE] Iteration 950: error = 1.5126231, gradient norm = 0.0000946 (50 iterations in 2.026s)
# [t-SNE] Iteration 1000: error = 1.4971808, gradient norm = 0.0000912 (50 iterations in 2.027s)
# [t-SNE] KL divergence after 1000 iterations: 1.497181
# Done..
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.480s...
# [t-SNE] Computed neighbors for 7352 samples in 41.412s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.252s
# [t-SNE] Iteration 50: error = 96.8985291, gradient norm = 0.0262291 (50 iterations in 3.327s)
# [t-SNE] Iteration 100: error = 84.1265106, gradient norm = 0.0061932 (50 iterations in 2.704s)
# [t-SNE] Iteration 150: error = 82.0755463, gradient norm = 0.0035207 (50 iterations in 2.452s)
# [t-SNE] Iteration 200: error = 81.3074036, gradient norm = 0.0029841 (50 iterations in 2.409s)
# [t-SNE] Iteration 250: error = 80.8985443, gradient norm = 0.0018447 (50 iterations in 2.348s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.898544
# [t-SNE] Iteration 300: error = 2.7042952, gradient norm = 0.0013134 (50 iterations in 2.347s)
# [t-SNE] Iteration 350: error = 2.1704030, gradient norm = 0.0005818 (50 iterations in 2.228s)
# [t-SNE] Iteration 400: error = 1.9191058, gradient norm = 0.0003557 (50 iterations in 2.244s)
# [t-SNE] Iteration 450: error = 1.7721289, gradient norm = 0.0002519 (50 iterations in 2.267s)
# [t-SNE] Iteration 500: error = 1.6780233, gradient norm = 0.0001923 (50 iterations in 2.317s)
# [t-SNE] Iteration 550: error = 1.6133283, gradient norm = 0.0001600 (50 iterations in 2.261s)
# [t-SNE] Iteration 600: error = 1.5662920, gradient norm = 0.0001366 (50 iterations in 2.295s)
# [t-SNE] Iteration 650: error = 1.5304862, gradient norm = 0.0001193 (50 iterations in 2.266s)
# [t-SNE] Iteration 700: error = 1.5027575, gradient norm = 0.0001092 (50 iterations in 2.264s)
# [t-SNE] Iteration 750: error = 1.4807982, gradient norm = 0.0000973 (50 iterations in 2.285s)
# [t-SNE] Iteration 800: error = 1.4628932, gradient norm = 0.0000919 (50 iterations in 2.263s)
# [t-SNE] Iteration 850: error = 1.4482260, gradient norm = 0.0000848 (50 iterations in 2.264s)
# [t-SNE] Iteration 900: error = 1.4359401, gradient norm = 0.0000792 (50 iterations in 2.264s)
# [t-SNE] Iteration 950: error = 1.4256471, gradient norm = 0.0000773 (50 iterations in 2.314s)
# [t-SNE] Iteration 1000: error = 1.4169967, gradient norm = 0.0000711 (50 iterations in 2.259s)
# [t-SNE] KL divergence after 1000 iterations: 1.416997
# Done..
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.479s...
# [t-SNE] Computed neighbors for 7352 samples in 42.951s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.629s
# [t-SNE] Iteration 50: error = 86.9043427, gradient norm = 0.0144349 (50 iterations in 3.903s)
# [t-SNE] Iteration 100: error = 75.5732346, gradient norm = 0.0038871 (50 iterations in 3.244s)
# [t-SNE] Iteration 150: error = 74.6427612, gradient norm = 0.0020614 (50 iterations in 2.955s)
# [t-SNE] Iteration 200: error = 74.3016052, gradient norm = 0.0018476 (50 iterations in 2.972s)
# [t-SNE] Iteration 250: error = 74.1284485, gradient norm = 0.0012014 (50 iterations in 3.009s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.128448
# [t-SNE] Iteration 300: error = 2.1539159, gradient norm = 0.0011923 (50 iterations in 2.932s)
# [t-SNE] Iteration 350: error = 1.7551177, gradient norm = 0.0004908 (50 iterations in 2.870s)
# [t-SNE] Iteration 400: error = 1.5859902, gradient norm = 0.0002801 (50 iterations in 2.850s)
# [t-SNE] Iteration 450: error = 1.4922380, gradient norm = 0.0001899 (50 iterations in 2.871s)
# [t-SNE] Iteration 500: error = 1.4323318, gradient norm = 0.0001398 (50 iterations in 2.847s)
# [t-SNE] Iteration 550: error = 1.3905319, gradient norm = 0.0001124 (50 iterations in 2.848s)
# [t-SNE] Iteration 600: error = 1.3617692, gradient norm = 0.0000960 (50 iterations in 2.877s)
# [t-SNE] Iteration 650: error = 1.3410897, gradient norm = 0.0000841 (50 iterations in 2.851s)
# [t-SNE] Iteration 700: error = 1.3255467, gradient norm = 0.0000745 (50 iterations in 2.868s)
# [t-SNE] Iteration 750: error = 1.3135266, gradient norm = 0.0000680 (50 iterations in 2.876s)
# [t-SNE] Iteration 800: error = 1.3042811, gradient norm = 0.0000634 (50 iterations in 2.911s)
# [t-SNE] Iteration 850: error = 1.2968264, gradient norm = 0.0000590 (50 iterations in 2.856s)
# [t-SNE] Iteration 900: error = 1.2909083, gradient norm = 0.0000567 (50 iterations in 2.880s)
# [t-SNE] Iteration 950: error = 1.2861243, gradient norm = 0.0000544 (50 iterations in 2.882s)
# [t-SNE] Iteration 1000: error = 1.2820443, gradient norm = 0.0000536 (50 iterations in 2.901s)
# [t-SNE] KL divergence after 1000 iterations: 1.282044
# Done..
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# # PREDICTION MODELS

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('UCI_HAR_Dataset/csv_files/train.csv')
test = pd.read_csv('UCI_HAR_Dataset/csv_files/test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %%
train.head(3)
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  Activity  ActivityName
# 0           0.288585          -0.020294  ...         5      STANDING
# 1           0.278419          -0.016411  ...         5      STANDING
# 2           0.279653          -0.019467  ...         5      STANDING
#
# [3 rows x 564 columns]

# %%
# get X_train and y_train from csv files
X_train = train.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_train = train.ActivityName

# %%
# get X_test and y_test from test csv file
X_test = test.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_test = test.ActivityName

# %%
print('X_train and y_train : ({},{})'.format(X_train.shape, y_train.shape))
print('X_test  and y_test  : ({},{})'.format(X_test.shape, y_test.shape))
# Out:
# X_train and y_train : ((7352, 561),(7352,))
# X_test  and y_test  : ((2947, 561),(2947,))

# %%
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %% [markdown]
# ### Function to plot the confusion matrix

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### Generic function to run any model specified

# %%
from datetime import datetime
def perform_model(model, X_train, y_train, X_test, y_test, class_labels, cm_normalize=True, \
                 print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    # to store results at various phases
    results = dict()
    
    # time at which model starts training 
    train_start_time = datetime.now()
    print('training the model..')
    model.fit(X_train, y_train)
    print('Done \n \n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('training_time(HH:MM:SS.ms) - {}\n\n'.format(results['training_time']))
    
    
    # predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results

# %% [markdown]
# ### Method to print the gridsearch Attributes

# %%
def print_grid_search_attributes(model):
    # Estimator that gave highest score among all the estimators formed in GridSearch
    print('--------------------------')
    print('|      Best Estimator     |')
    print('--------------------------')
    print('\n\t{}\n'.format(model.best_estimator_))


    # parameters that gave best results while performing grid search
    print('--------------------------')
    print('|     Best parameters     |')
    print('--------------------------')
    print('\tParameters of best estimator : \n\n\t{}\n'.format(model.best_params_))


    #  number of cross validation splits
    print('---------------------------------')
    print('|   No of CrossValidation sets   |')
    print('--------------------------------')
    print('\n\tTotal numbre of cross validation sets: {}\n'.format(model.n_splits_))


    # Average cross validated score of the best estimator, from the Grid Search 
    print('--------------------------')
    print('|        Best Score       |')
    print('--------------------------')
    print('\n\tAverage Cross Validate scores of best estimator : \n\n\t{}\n'.format(model.best_score_))

# %% [markdown]
# ## Logistic Regression with Grid Search

# %%
from sklearn import linear_model
from sklearn import metrics

from sklearn.model_selection import GridSearchCV

# %%
# start Grid search
parameters = {'C':[0.01, 0.1, 1, 10, 20, 30], 'penalty':['l2','l1']}
log_reg = linear_model.LogisticRegression()
log_reg_grid = GridSearchCV(log_reg, param_grid=parameters, cv=3, verbose=1, n_jobs=-1)
log_reg_grid_results =  perform_model(log_reg_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:   24.6s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:27.517494
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.009245
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9579233118425518
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 429  59   0   0   3]
#  [  0  15 517   0   0   0]
#  [  0   0   0 492   3   1]
#  [  0   0   0   4 403  13]
#  [  0   0   0  25   1 445]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.87      0.92       491
#           STANDING       0.90      0.97      0.93       532
#            WALKING       0.94      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.96      0.97       420
#   WALKING_UPSTAIRS       0.96      0.94      0.95       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(log_reg_grid_results['confusion_matrix'], classes=labels, cmap=plt.cm.Greens, )
plt.show()

# %%
# observe the attributes of the model 
print_grid_search_attributes(log_reg_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 1, 'penalty': 'l2'}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 3
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9374335617559958

# %% [markdown]
# ## Linear SVC with GridSearch

# %%
from sklearn.svm import LinearSVC

# %%
parameters = {'C':[0.125, 0.5, 1, 2, 8, 16]}
lr_svc = LinearSVC(tol=0.00005)
lr_svc_grid = GridSearchCV(lr_svc, param_grid=parameters, n_jobs=-1, verbose=1)
lr_svc_grid_results = perform_model(lr_svc_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  1.4min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:01:26.367781
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.009109
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9660671869697998
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  2 427  58   0   0   4]
#  [  0  10 521   1   0   0]
#  [  0   0   0 496   0   0]
#  [  0   0   0   2 412   6]
#  [  0   0   0  17   0 454]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.87      0.92       491
#           STANDING       0.90      0.98      0.94       532
#            WALKING       0.96      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.96      0.97       471
#
#           accuracy                           0.97      2947
#          macro avg       0.97      0.97      0.97      2947
#       weighted avg       0.97      0.97      0.97      2947

# %%
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(lr_svc_grid_results['confusion_matrix'], classes=labels, cmap=plt.cm.Greens, )
plt.show()

# %%
print_grid_search_attributes(lr_svc_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LinearSVC(C=1, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=5e-05,
#           verbose=0)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 1}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9420636616305258

# %% [markdown]
# ## Kernel SVM with GridSearch

# %%
from sklearn.svm import SVC
parameters = {'C':[2,8,16],\
              'gamma': [ 0.0078125, 0.125, 2]}
rbf_svm = SVC(kernel='rbf')
rbf_svm_grid = GridSearchCV(rbf_svm,param_grid=parameters, n_jobs=-1)
rbf_svm_grid_results = perform_model(rbf_svm_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:13:21.595409
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:03.016024
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9626739056667798
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 441  48   0   0   2]
#  [  0  12 520   0   0   0]
#  [  0   0   0 489   2   5]
#  [  0   0   0   4 397  19]
#  [  0   0   0  17   1 453]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.90      0.93       491
#           STANDING       0.92      0.98      0.95       532
#            WALKING       0.96      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.95      0.97       420
#   WALKING_UPSTAIRS       0.95      0.96      0.95       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(rbf_svm_grid_results['confusion_matrix'], classes=labels, cmap=plt.cm.Greens, )
plt.show()

# %%
print_grid_search_attributes(rbf_svm_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	SVC(C=16, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.0078125, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 16, 'gamma': 0.0078125}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9447834551903698

# %%
print('\n                     Accuracy     Error')
print('                     ----------   --------')
print('Logistic Regression : {:.04}%       {:.04}%'.format(log_reg_grid_results['accuracy'] * 100,\
                                                  100-(log_reg_grid_results['accuracy'] * 100)))

print('Linear SVC          : {:.04}%       {:.04}% '.format(lr_svc_grid_results['accuracy'] * 100,\
                                                        100-(lr_svc_grid_results['accuracy'] * 100)))

print('rbf SVM classifier  : {:.04}%      {:.04}% '.format(rbf_svm_grid_results['accuracy'] * 100,\
                                                          100-(rbf_svm_grid_results['accuracy'] * 100)))
# Out:
#                      Accuracy     Error
#                      ----------   --------
# Logistic Regression : 95.79%       4.208%
# Linear SVC          : 96.61%       3.393%
# rbf SVM classifier  : 96.27%      3.733%
